# %% [markdown]
# <a href="https://colab.research.google.com/github/jqshang/CSC2529/blob/main/Experiments/data_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jqshang/CSC2529.git
# %cd CSC2529/dataset/utils
# Out:
# Cloning into 'CSC2529'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 24 (delta 5), reused 18 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 13.88 KiB | 1.73 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/CSC2529/dataset/utils

# %%
# !pip install -r ../../requirements.txt
# !sudo apt-get update
# !sudo apt-get install -y exiftool
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 47.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 67.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 103.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 59.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 76.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Download

# %%
# !mkdir /content/data
# !mkdir /content/data/fivek_dataset
# !mkdir /content/data/fivek_dataset_processed

# %%
from fivek_dataset import MITAboveFiveK
fivek = MITAboveFiveK(root="/content/data/", split="debug", download=True)

# %% [markdown]
# # Preprocess

# %%
# !cp /content/data/MITAboveFiveK/raw/Canon_EOS_5D/* /content/data/fivek_dataset

# %%
# !python3 preprocess.py
# Out:
# load meta data from raw files
# Canon EOS 5D
# Canon EOS 5D
# process Canon EOS 5D
# 2 images
# train (1 images)
# a1525-jmac_MG_0646
# test (1 images)
# a1882-07-11-23-at-17h04m28s-_MG_6574
